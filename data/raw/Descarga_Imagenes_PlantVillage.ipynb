# %% [markdown]
# # Proyecto de Grado: IA al servicio de las comunidades
# Descarga imagenes de hojas
#
# Datos tomados de: https://github.com/spMohanty/PlantVillage-Dataset/tree/master/raw
#
# **Nombres:** María Fernanda Izquierdo Aparicio & Ana María Ochoa Muñoz
#
# **Fecha:** 11 de Marzo de 2025

# %% [markdown]
# ## 1. Instalación de paquete de git para hacer la conexion con el repositorio de los datos.

# %%
pip install gitpython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import git

# %%
repo_url = "https://github.com/spMohanty/PlantVillage-Dataset"
destination = "PlantVillage-Dataset 2"

git.Repo.clone_from(repo_url, destination)
print("Repositorio clonado exitosamente.")
# Out:
# Repositorio clonado exitosamente.
