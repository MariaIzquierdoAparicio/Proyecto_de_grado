# %% [markdown]
# Datos Balanceados

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Ruta de la carpeta
directory_root = Path("~/Documents/MFIA - PUJ - Maestría/Proyecto de Grado/0. Data/Datos Balanceados").expanduser()

# Obtener la lista de carpetas, ignorando archivos ocultos
carpetas = [f for f in directory_root.iterdir() if f.is_dir()]

# Lista para almacenar los datos
data = []

# Recorrer cada carpeta
for carpeta in carpetas:
    archivos = list(carpeta.glob("*"))  # Obtener todos los archivos dentro de la carpeta
    
    if archivos:  # Verificar si hay imágenes en la carpeta
        data.extend([[carpeta.name, archivo.name] for archivo in archivos])

# Crear el DataFrame
df = pd.DataFrame(data, columns=["Carpeta", "Nombre del archivo"])

# Separar la columna "Carpeta" en "Planta" y "Condición"
#df[["Planta", "Condición"]] = df["Carpeta"].str.split("-", expand=True)

# Crear la columna "Saludable"
#df["Saludable"] = np.where(df["Condición"] == "healthy", "Sí", "No")

# Guardar en CSV
df.to_csv("archivos_plantpad.csv", index=False)

# %%
# Mostrar estadísticas generales
print("Resumen del DataFrame:")
print(df.describe(include="all"))

# Mostrar distribución de datos
print("\nFrecuencia de cada planta:")
print(df["Planta"].value_counts())

print("\nFrecuencia de cada condición:")
print(df["Condición"].value_counts())

print("\nConteo de imágenes saludables vs. no saludables:")
print(df["Saludable"].value_counts())

# Muestra aleatoria de datos
print("\nMuestra de 10 filas aleatorias:")
print(df.sample(10, random_state=42))
# Out:
# Resumen del DataFrame:
#           Carpeta                   Nombre del archivo Planta Condición  \
# count        2643                                 2643   2643      2643
# unique          9                                 2643      3         7
# top     bean-rust  cauliflower_Downy Mildew. (130).jpg   bean   healthy
# freq          436                                    1   1296       975
#
#        Saludable
# count       2643
# unique         2
# top           No
# freq        1668
#
# Frecuencia de cada planta:
# Planta
# bean           1296
# cucumber        691
# cauliflower     656
# Name: count, dtype: int64
#
# Frecuencia de cada condición:
# Condición
# healthy               975
# rust                  436
# angular_leaf_spot     432
# diseased              350
# downy_mildew          177
# bacterial_spot_rot    173
# black_rot             100
# Name: count, dtype: int64
#
# Conteo de imágenes saludables vs. no saludables:
# Saludable
# No    1668
# Sí     975
# Name: count, dtype: int64
#
# Muestra de 10 filas aleatorias:
#                      Carpeta                   Nombre del archivo  \
# 889   bean-angular_leaf_spot  bean_angular_leaf_spot_train.21.jpg
# 1110     cauliflower-healthy     cauliflower_No disease. (47).jpg
# 1309               bean-rust         bean_bean_rust_train.149.jpg
# 727   bean-angular_leaf_spot  bean_angular_leaf_spot_train.69.jpg
# 1027     cauliflower-healthy     cauliflower_No disease. (25).jpg
# 1472               bean-rust         bean_bean_rust_train.125.jpg
# 748   bean-angular_leaf_spot   bean_angular_leaf_spot_train.4.jpg
# 1264               bean-rust          bean_bean_rust_train.57.jpg
# 2616       cucumber-diseased    cucumber_IMG20200629182104_01.jpg
# 1612               bean-rust         bean_bean_rust_train.190.jpg
#
#            Planta          Condición Saludable
# 889          bean  angular_leaf_spot        No
# 1110  cauliflower            healthy        Sí
# 1309         bean               rust        No
# 727          bean  angular_leaf_spot        No
# 1027  cauliflower            healthy        Sí
# 1472         bean               rust        No
# 748          bean  angular_leaf_spot        No
# 1264         bean               rust        No
# 2616     cucumber           diseased        No
# 1612         bean               rust        No
