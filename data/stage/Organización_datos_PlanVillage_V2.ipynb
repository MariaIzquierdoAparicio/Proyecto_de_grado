# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Ruta de la carpeta
directory_root = Path("~/Documents/MFIA - PUJ - Maestría/Proyecto de Grado/PlantVillage-Dataset/raw/color").expanduser()

# Obtener la lista de carpetas, ignorando archivos ocultos
carpetas = [f for f in directory_root.iterdir() if f.is_dir()]

# Lista para almacenar los datos
data = []

# Recorrer cada carpeta
for carpeta in carpetas:
    archivos = list(carpeta.glob("*"))  # Obtener todos los archivos dentro de la carpeta
    
    if archivos:  # Verificar si hay imágenes en la carpeta
        data.extend([[carpeta.name, archivo.name] for archivo in archivos])

# Crear el DataFrame
df = pd.DataFrame(data, columns=["Carpeta", "Nombre del archivo"])

# Separar la columna "Carpeta" en "Planta" y "Condición"
df[["Planta", "Condición"]] = df["Carpeta"].str.split("___", expand=True)

# Crear la columna "Saludable"
df["Saludable"] = np.where(df["Condición"] == "healthy", "Sí", "No")

# Guardar en CSV
df.to_csv("archivos_plantvillage.csv", index=False)

# %%
# Mostrar estadísticas generales
print("Resumen del DataFrame:")
print(df.describe(include="all"))

# Mostrar distribución de datos
print("\nFrecuencia de cada planta:")
print(df["Planta"].value_counts())

print("\nFrecuencia de cada condición:")
print(df["Condición"].value_counts())

print("\nConteo de imágenes saludables vs. no saludables:")
print(df["Saludable"].value_counts())

# Muestra aleatoria de datos
print("\nMuestra de 10 filas aleatorias:")
print(df.sample(10, random_state=42))
# Out:
# Resumen del DataFrame:
#                                          Carpeta  \
# count                                      43244
# unique                                        31
# top     Orange___Haunglongbing_(Citrus_greening)
# freq                                        5507
#
#                                        Nombre del archivo  Planta Condición  \
# count                                               43244   43244     43244
# unique                                              43244       9        20
# top     8f558908-aa1b-4a86-855a-5094c2392e5a___RS_HL 1...  Tomato   healthy
# freq                                                    1   18160      6907
#
#        Saludable
# count      43244
# unique         2
# top           No
# freq       36337
#
# Frecuencia de cada planta:
# Planta
# Tomato          18160
# Orange           5507
# Grape            4062
# Corn_(maize)     3852
# Apple            3174
# Pepper,_bell     2475
# Peach            2297
# Potato           2152
# Strawberry       1565
# Name: count, dtype: int64
#
# Frecuencia de cada condición:
# Condición
# healthy                                 6907
# Haunglongbing_(Citrus_greening)         5507
# Bacterial_spot                          5421
# Tomato_Yellow_Leaf_Curl_Virus           5357
# Late_blight                             2909
# Early_blight                            2000
# Black_rot                               1801
# Septoria_leaf_spot                      1771
# Spider_mites Two-spotted_spider_mite    1676
# Target_Spot                             1404
# Esca_(Black_Measles)                    1383
# Common_rust_                            1192
# Leaf_scorch                             1109
# Leaf_blight_(Isariopsis_Leaf_Spot)      1076
# Northern_Leaf_Blight                     985
# Leaf_Mold                                952
# Apple_scab                               633
# Cercospora_leaf_spot Gray_leaf_spot      513
# Tomato_mosaic_virus                      373
# Cedar_apple_rust                         275
# Name: count, dtype: int64
#
# Conteo de imágenes saludables vs. no saludables:
# Saludable
# No    36337
# Sí     6907
# Name: count, dtype: int64
#
# Muestra de 10 filas aleatorias:
#                                       Carpeta  \
# 22893            Grape___Esca_(Black_Measles)
# 27054  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 19358                 Tomato___Bacterial_spot
# 41227                         Apple___healthy
# 20813                   Tomato___Early_blight
# 25631  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 9126                   Pepper,_bell___healthy
# 39725                       Apple___Black_rot
# 34146                  Peach___Bacterial_spot
# 15757                      Tomato___Leaf_Mold
#
#                                       Nombre del archivo        Planta  \
# 22893  1e094cfe-006b-456f-9d19-151c85e281e3___FAM_B.M...         Grape
# 27054  d66188e3-b110-4a80-bedc-faaec8f50957___UF.GRC_...        Tomato
# 19358  cdd6b4c8-6be0-4cc8-81a7-4e0c5ba16fed___GCREC_B...        Tomato
# 41227  044a96a2-d5ac-490b-8c57-2c1859cdf8f3___RS_HL 7...         Apple
# 20813  18a21f42-8794-4665-8174-b0ccd3758af8___RS_Erly...        Tomato
# 25631  c80105d0-0614-4bb1-9490-02b911d94703___YLCV_GC...        Tomato
# 9126   978258d9-3b2f-4368-80aa-3288d2e40b7f___JR_HL 7...  Pepper,_bell
# 39725  5984db18-75d7-4c3a-be4b-74c3c0351887___JR_FrgE...         Apple
# 34146  f51d0529-b089-4d5b-af63-340b6b9f5b5e___Rutg._B...         Peach
# 15757  447ca40f-8640-43d7-b7af-3372e8afbfba___Crnl_L....        Tomato
#
#                            Condición Saludable
# 22893           Esca_(Black_Measles)        No
# 27054  Tomato_Yellow_Leaf_Curl_Virus        No
# 19358                 Bacterial_spot        No
# 41227                        healthy        Sí
# 20813                   Early_blight        No
# 25631  Tomato_Yellow_Leaf_Curl_Virus        No
# 9126                         healthy        Sí
# 39725                      Black_rot        No
# 34146                 Bacterial_spot        No
# 15757                      Leaf_Mold        No
